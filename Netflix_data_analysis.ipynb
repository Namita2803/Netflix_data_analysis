# %% [markdown]
# <a href="https://colab.research.google.com/github/Namita2803/Netflix_data_analysis/blob/main/Netflix_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Use the correct filename here 👇
df = pd.read_csv('netflix_titles_nov_2019.csv')

# Show first 5 rows
df.head()
# Out:
#                                  title                    director  \
# 0                            Chocolate                         NaN
# 1  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2                      The Zoya Factor             Abhishek Sharma
# 3                            Atlantics                   Mati Diop
# 4                      Chip and Potato                         NaN
#
#                                                 cast  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                  Christian Morales
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4  Abigail Oliver, Andrea Libman, Briana Buckmast...
#
#                     country         date_added  release_year rating  \
# 0               South Korea  November 30, 2019          2019  TV-14
# 1                       NaN  November 30, 2019          2019   TV-G
# ...

# %%
# Check the number of rows and columns
print("Shape of dataset:", df.shape)

# Show column names and data types
print("\nData types:\n", df.dtypes)

# Count missing (null) values in each column
print("\nMissing values:\n", df.isnull().sum())

# Show overall summary info
df.info()
# Out:
# Shape of dataset: (5837, 12)
#
# Data types:
#  title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# type            object
# show_id         object
# dtype: object
#
# Missing values:
#  title              0
# director        1901
# cast             556
# country          427
# date_added       642
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# type               0
# show_id            0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5837 entries, 0 to 5836
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         5837 non-null   object
#  1   director      3936 non-null   object
# ...

# %%
# Shape of the dataset: (rows, columns)
print("Shape of the dataset:", df.shape)

# Check column names and their data types
print("\nColumn Data Types:\n")
print(df.dtypes)

# Check for missing (null) values in each column
print("\nMissing Values in Each Column:\n")
print(df.isnull().sum())

# Quick overview of the dataset
print("\nDataset Info:\n")
df.info()
# Out:
# Shape of the dataset: (5837, 12)
#
# Column Data Types:
#
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# type            object
# show_id         object
# dtype: object
#
# Missing Values in Each Column:
#
# title              0
# director        1901
# cast             556
# country          427
# date_added       642
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# type               0
# show_id            0
# dtype: int64
#
# Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5837 entries, 0 to 5836
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         5837 non-null   object
# ...

# %%
# Convert 'date_added' column to datetime format
df['date_added'] = pd.to_datetime(df['date_added'])

# Check again
df['date_added'].head()
# Out:
# 0   2019-11-30
# 1   2019-11-30
# 2   2019-11-30
# 3   2019-11-29
# 4          NaT
# Name: date_added, dtype: datetime64[ns]

# %%
df.isnull().sum()
# Out:
# title              0
# director        1901
# cast             556
# country          427
# date_added       642
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# type               0
# show_id            0
# dtype: int64

# %%
# Keep only rows where 'date_added' is not null
df = df[df['date_added'].notnull()]

# %%
df.shape
# Out:
# (5195, 12)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set a clean style
sns.set(style="whitegrid")

# Plot count of Movies and TV Shows
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='type', palette='pastel')

plt.title('Count of Movies vs TV Shows on Netflix')
plt.xlabel('Type of Content')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-9-1402563334>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='type', palette='pastel')

# %%
 # Fill missing values in 'country' with 'Unknown'
df['country'].fillna('Unknown', inplace=True)

# If multiple countries are listed, take only the first one
df['country'] = df['country'].apply(lambda x: x.split(',')[0])

# Count top 10 countries
top_countries = df['country'].value_counts().head(10)

# Plot it
plt.figure(figsize=(10, 5))
sns.barplot(x=top_countries.values, y=top_countries.index, palette='Set3')

plt.title('Top 10 Countries with Most Netflix Content')
plt.xlabel('Number of Titles')
plt.ylabel('Country')
plt.show()
# Out:
# <ipython-input-10-2098196184>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna('Unknown', inplace=True)
# <ipython-input-10-2098196184>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.values, y=top_countries.index, palette='Set3')

# %%
# Convert 'date_added' to datetime format
df['date_added'] = pd.to_datetime(df['date_added'])

# Extract year from 'date_added'
df['year_added'] = df['date_added'].dt.year

# Count of content added each year (drop nulls)
yearly_data = df['year_added'].value_counts().dropna().sort_index()

# Plotting
plt.figure(figsize=(12, 6))
sns.lineplot(x=yearly_data.index, y=yearly_data.values, marker='o', color='crimson')

plt.title('Content Added to Netflix Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Titles Added')
plt.grid(True)
plt.show()

# %%
from collections import Counter

# Drop missing values in 'listed_in'
genre_data = df['listed_in'].dropna()

# Split by comma, flatten into one list
all_genres = []
for item in genre_data:
    genres = item.split(',')
    for genre in genres:
        all_genres.append(genre.strip())

# Count top genres
genre_counts = Counter(all_genres).most_common(10)

# Convert to DataFrame for plotting
genre_df = pd.DataFrame(genre_counts, columns=['Genre', 'Count'])

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(data=genre_df, x='Count', y='Genre', palette='coolwarm')
plt.title('Top 10 Most Popular Netflix Genres (Overall)')
plt.xlabel('Number of Titles')
plt.ylabel('Genre')
plt.show()
# Out:
# <ipython-input-12-40328975>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=genre_df, x='Count', y='Genre', palette='coolwarm')

# %%
# Filter data for Movies and TV Shows
movies_df = df[df['type'] == 'Movie']
tvshows_df = df[df['type'] == 'TV Show']

# %%
def get_top_genres(dataframe, column='listed_in', top_n=10):
    all_genres = []
    for item in dataframe[column].dropna():
        genres = item.split(',')
        all_genres.extend([genre.strip() for genre in genres])

    genre_count = Counter(all_genres).most_common(top_n)
    return pd.DataFrame(genre_count, columns=['Genre', 'Count'])

# %%
top_movie_genres = get_top_genres(movies_df)
top_tv_genres = get_top_genres(tvshows_df)

# %%
# Plotting both
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.barplot(data=top_movie_genres, x='Count', y='Genre', palette='Reds', ax=axes[0])
axes[0].set_title('Top Genres in Movies')
axes[0].set_xlabel('Count')
axes[0].set_ylabel('Genre')

sns.barplot(data=top_tv_genres, x='Count', y='Genre', palette='Blues', ax=axes[1])
axes[1].set_title('Top Genres in TV Shows')
axes[1].set_xlabel('Count')
axes[1].set_ylabel('')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-16-2096382426>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_movie_genres, x='Count', y='Genre', palette='Reds', ax=axes[0])
# <ipython-input-16-2096382426>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_tv_genres, x='Count', y='Genre', palette='Blues', ax=axes[1])

# %%
# Filter only Movies
movie_durations = movies_df.copy()

# Keep only the numeric part (e.g., "90 min" → 90)
movie_durations['duration'] = movie_durations['duration'].str.replace(' min', '')
movie_durations = movie_durations[movie_durations['duration'].str.isdigit()]
movie_durations['duration'] = movie_durations['duration'].astype(int)

# Plot distribution
plt.figure(figsize=(10, 5))
sns.histplot(movie_durations['duration'], bins=30, kde=True, color='orange')
plt.title('Distribution of Movie Durations')
plt.xlabel('Duration (minutes)')
plt.ylabel('Number of Movies')
plt.grid(True)
plt.show()

# %%
# Make a copy of TV Shows data
tv_durations = tvshows_df.copy()

# Clean the 'duration' column to extract number of seasons
tv_durations['duration'] = tv_durations['duration'].str.replace(' Season', '', regex=False)
tv_durations['duration'] = tv_durations['duration'].str.replace(' Seasons', '', regex=False)

# Filter numeric values
tv_durations = tv_durations[tv_durations['duration'].str.isdigit()]
tv_durations['duration'] = tv_durations['duration'].astype(int)

# Count frequency of seasons
season_counts = tv_durations['duration'].value_counts().sort_index()

# Plot
plt.figure(figsize=(10, 5))
sns.barplot(x=season_counts.index, y=season_counts.values, palette='Purples')
plt.title('Number of TV Shows by Seasons')
plt.xlabel('Number of Seasons')
plt.ylabel('Count of TV Shows')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-18-87658240>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=season_counts.index, y=season_counts.values, palette='Purples')

# %%
# Search for rows where title contains 'Stranger Things'
df[df['title'].str.contains('Stranger Things', case=False, na=False)]
# Out:
#                        title director  \
# 4146  Beyond Stranger Things      NaN
#
#                                                    cast        country  \
# 4146  Jim Rash, Matt Duffer, Ross Duffer, Shawn Levy...  United States
#
#      date_added  release_year rating  duration  \
# 4146 2017-10-27          2017  TV-14  1 Season
#
#                                               listed_in  \
# 4146  Stand-Up Comedy & Talk Shows, TV Mysteries, TV...
#
#                                             description     type    show_id  \
# 4146  Secrets from the "Stranger Things 2" universe ...  TV Show  80197912/
#
#       year_added
# 4146        2017

# %%
# Save cleaned dataset for Power BI
df.to_csv('cleaned_netflix_data.csv', index=False)

# %%
from google.colab import files
files.download('cleaned_netflix_data.csv')
